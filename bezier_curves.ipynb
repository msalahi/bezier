# %%
# %pylab inline
plt.style.use('bmh')
from bezierplot import plot_bezier_curve
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
control_points = [(0, 1), (0, 0), (1, 0), (.5, 1)]
plot_bezier_curve(control_points)
